# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import os
import scipy.stats as stats
import matplotlib.pyplot as plt
import json
import re
# %matplotlib inline

# %%
# GET THREE VOTATIONS PER YEAR

# get content from url: replace HTM by filter (it is the URL of "toc)
r = requests.get('https://www.admin.ch/ch/f/pore/va/vab_2_2_4_1_2011_2020.html')
soup = BeautifulSoup(r.content) #get the tree with beatifulsoup
print(soup.prettify()) # present the url content in a nice way
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html class="no-js no-ie" xmlns:fn="http://www.w3.org/2005/xpath-functions" xmlns:xs="http://www.w3.org/2001/XMLSchema">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Répertoire chronologique
#   </title>
#   <meta content="" name="description"/>
#   <meta content="
# 			Swizzera, Administration, design, logo, image, identity
# 		" name="keywords"/>
#   <meta content="IE=edge,chrome=$start" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="/ch/styles/css/vendors.css" rel="stylesheet"/>
#   <link href="/ch/styles/css/admin.css" rel="stylesheet"/>
#   <link href="/ch/styles/css/print.css" rel="stylesheet"/>
#   <link href="/ch/styles/img/ico/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# GET VOTATIONS IN A GIVEN SESSION

# get content from url: replace HTM by filter (it is the URL of "toc)
r = requests.get('https://www.admin.ch/ch/f/pore/va/20160228/index.html')
soup = BeautifulSoup(r.content) #get the tree with beatifulsoup
print(soup.prettify()) # present the url content in a nice way
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html class="no-js no-ie" xmlns:fn="http://www.w3.org/2005/xpath-functions" xmlns:xs="http://www.w3.org/2001/XMLSchema">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Votation populaire du 28.02.2016
#   </title>
#   <meta content="" name="description"/>
#   <meta content="
# 			Swizzera, Administration, design, logo, image, identity
# 		" name="keywords"/>
#   <meta content="IE=edge,chrome=$start" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="/ch/styles/css/vendors.css" rel="stylesheet"/>
#   <link href="/ch/styles/css/admin.css" rel="stylesheet"/>
#   <link href="/ch/styles/css/print.css" rel="stylesheet"/>
#   <link href="/ch/styles/img/ico/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# GET TABLE FOR A GIVEN VOTE IN A GIVEN SESSION

r = requests.get('https://www.admin.ch/ch/f/pore/va/20160228/can596.html')
soup = BeautifulSoup(r.content) #get the tree with beatifulsoup
print(soup.prettify()) # present the url content in a nice way
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html class="no-js no-ie" xmlns:fn="http://www.w3.org/2005/xpath-functions" xmlns:xs="http://www.w3.org/2001/XMLSchema">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Votation No 596
#   </title>
#   <meta content="" name="description"/>
#   <meta content="
# 			Swizzera, Administration, design, logo, image, identity
# 		" name="keywords"/>
#   <meta content="IE=edge,chrome=$start" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="/ch/styles/css/vendors.css" rel="stylesheet"/>
#   <link href="/ch/styles/css/admin.css" rel="stylesheet"/>
#   <link href="/ch/styles/css/print.css" rel="stylesheet"/>
#   <link href="/ch/styles/img/ico/favicon.ico" rel="shortcut icon"/>
# ...

# %%
info = soup.find_all('table')[0]
info
# Out:
# <table class="table table-bordered text-center table-striped" xmlns:ns="http://www.tempuri.org/XML">
# <thead>
# <tr>
# <td class="text-left" scope="col">Canton</td>
# <td align="center" scope="col">Electeurs</td>
# <td align="center" scope="col">Votants</td>
# <td align="center" scope="col">% Particip.</td>
# <td align="center" scope="col">Oui</td>
# <td align="center" scope="col">Non</td>
# <td align="center" scope="col">% Oui</td>
# <td align="center" scope="col">% Non</td>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-left">Zurich</td>
# <td class="text-right">912'538</td>
# <td align="center">593'633</td>
# <td align="center">65.05%</td>
# <td align="center">253'697</td>
# <td align="center">329'992</td>
# <td align="center">43.5%</td>
# <td align="center">56.5%</td>
# </tr>
# <tr>
# <td class="text-left">Berne</td>
# <td class="text-right">730'450</td>
# <td align="center">449'836</td>
# <td align="center">61.58%</td>
# <td align="center">202'291</td>
# ...

# %%
# The first tr contains the field names
# Define the names of the fields

field_names = []
for field in table.find("thead").find_all('td'):
    field_names.append(field.text)
    
print(field_names)
# Out:
# Canton
# Electeurs
# Votants
# % Particip.
# Oui
# Non
# % Oui
# % Non
# ['Canton', 'Electeurs', 'Votants', '% Particip.', 'Oui', 'Non', '% Oui', '% Non']

# %%
# Create a pandas DataFrame with those columns
table = pd.DataFrame(columns = field_names)
table
# Out:
# Empty DataFrame
# Columns: [Canton, Electeurs, Votants, % Particip., Oui, Non, % Oui, % Non]
# Index: []
